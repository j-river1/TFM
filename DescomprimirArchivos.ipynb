# %% [markdown]
# <a href="https://colab.research.google.com/github/j-river1/TFM/blob/master/DescomprimirArchivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **How to read Nibabel images**
#
# First we load some libraries we are going to need for the examples

# %%
import os
import numpy as np
import glob
import tarfile
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# # Acceder a Google Drive

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# # Cambiar directorio
# Para conocer la actual ubicación.

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/My Drive/Colab Notebooks/TFM/Datos/IXI-T1
# Out:
# /content/drive/My Drive/Colab Notebooks/TFM/Datos/IXI-T1

# %% [markdown]
# # Extraer los archivos
# Se descomprime los archivos guardados usando 7zip

# %%
# !apt-get install p7zip-full
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-6).
# 0 upgraded, 0 newly installed, 0 to remove and 6 not upgraded.

# %%
!7za x '/content/drive/My Drive/Colab Notebooks/TFM/Datos/IXI-T1.tar'
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 4840816640 bytes (4617 MiB)
#
# Extracting archive: /content/drive/My Drive/Colab Notebooks/TFM/Datos/IXI-T1.tar
# --
# Path = /content/drive/My Drive/Colab Notebooks/TFM/Datos/IXI-T1.tar
# Type = tar
# Physical Size = 4840816640
# Headers Size = 306176
# Code Page = UTF-8
#
#   0%
# Would you like to replace the existing file:
#   Path:     ./IXI002-Guys-0828-T1.nii.gz
#   Size:     6943524 bytes (6781 KiB)
#   Modified: 2007-09-27 09:25:16
# with the file from archive:
#   Path:     IXI002-Guys-0828-T1.nii.gz
#   Size:     6943524 bytes (6781 KiB)
#   Modified: 2007-09-27 09:25:15
# ? (Y)es / (N)o / (A)lways / (S)kip all / A(u)to rename all / (Q)uit? A
#
# Everything is Ok
#
# Files: 581
# Size:       4840367627
# Compressed: 4840816640

# %% [markdown]
# We load the file to create a nibabel image object:
